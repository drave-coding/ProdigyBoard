# %%
from serpapi import GoogleSearch
import pandas as pd

params = {
  "engine": "google_maps",
  "q": "hotel",
  "ll": "@28.704060, 77.102493, 15.1z",
  "type": "search",
  "api_key": "f57f5bf91391871d7e4a44426d93fbf9238020117d6ee868c3db436b95864ae6"
}

search = GoogleSearch(params)
results = search.get_dict()
local_results = results["local_results"]

# %%
df = pd.json_normalize(results["local_results"])

# %%
df.columns
# Out:
# Index(['position', 'title', 'place_id', 'data_id', 'data_cid', 'reviews_link',
#        'photos_link', 'place_id_search', 'provider_id', 'rating', 'reviews',
#        'price', 'type', 'types', 'type_id', 'type_ids', 'address', 'phone',
#        'website', 'description', 'amenities', 'thumbnail',
#        'gps_coordinates.latitude', 'gps_coordinates.longitude',
#        'unclaimed_listing'],
#       dtype='object')

# %%
columns = ['position', 'title', 'address', 'phone', 'website', 'description', 'amenities','rating', 'reviews','price',
          'type_id', 'type_ids', 'place_id', 'data_id' ,'reviews_link', 'provider_id']
df2 = df[columns]

# %%
df2
# Out:
#     position                                              title  \
# 0          1        Crowne Plaza New Delhi Rohini, an IHG Hotel
# 1          2                                   Seven Seas Hotel
# 2          3                               Treebo MVM Residency
# 3          4                           Hotel Green Arrow Rohini
# 4          5                               Hotel Goel Residency
# 5          6                      FabHotel Moro Rohini Sector 4
# 6          7                                       Svaruchi Inn
# 7          8                             Royal Residency Rohini
# 8          9              Ramada by Wyndham New Delhi Pitampura
# 9         10  Hotel Shine inn Rooms .Near Rohini west metro ...
# 10        11  Super Townhouse Pitampura West Enclave Company...
# 11        12                                   Runway Residency
# 12        13                  Sun Moon Residency and Apartments
# 13        14                  Flagship 74192 Vishwakarma Palace
# 14        15                                 vishwakarma palace
# 15        16                         OYO Flagship Mvm Residency
# 16        17                                 Treebo Stellar Inn
# 17        18                                  OYO Amazing House
# 18        19                   Florence Residency & Riviera inn
# 19        20                                   Travellers Hotel
#
#                                               address             phone  \
# 0   Twin District Centre, Swarn Jayanti Park, Sect...  +91 11 4488 4488
# 1   12, M2K Rd, Mangalam Place, Rohini, New Delhi,...  +91 11 4340 0000
# 2   Property bearing no 15, Block A, Pocket 3, Sec...   +91 93228 00100
# 3   Hargovind Vihar, A 02, Sir Chotu Ram Marg, nea...               NaN
# 4   A-1/84, Sector-8, Rohini, Near Rohini East Met...   +91 98112 90690
# 5   C, 48/49, 40 Feet Rd, near Saint Giri School, ...   +91 70424 24242
# 6   E1/10, near M2k Cinemas, Pocket 2, Sector 7, R...   +91 73033 77233
# 7   B-3/357, near Rajiv Gandhi Cancer institute, P...               NaN
# 8   Plot No 10, Rd Number 42, Co-operative Group H...  +91 11 2703 5353
# 9   Pocket No. H-32, House No.18, 85, near Vishram...  +91 11 3535 5755
# 10  HOTEL, Plot no-5, near Rajya Sabha, Rajdhani E...  +91 124 433 0599
# 11  Plot No.C, 569, Saraswati Vihar Rd, Block B, L...   +91 97110 78079
# 12  56, 57 - C4, Sector 6 Rd, Pocket 4, Sector 6, ...   +91 84474 57467
# 13  A-02 A-02, Sir Chotu Ram Marg, Hargovind Vihar...  +91 124 620 1616
# 14  HAR GOBIND VIHAR, A-02, Sir Chotu Ram Marg, ne...               NaN
# 15  A-3/15, Sector 3, Sector 3D, Rohini, Delhi, Ne...  +91 124 458 8630
# 16  CSC 1, DDA Market, Shukar Bazar Road, Sector 6...   +91 93228 00100
# 17  A, 1, Budh Vihar Phase I, Budh Vihar, Delhi, 1...  +91 124 620 1616
# 18  C9/116, c block road, Halar Rd, nr. rohini eas...   +91 98102 70941
# 19  Plot No-1&2, Sir Chotu Ram Marg, near Rajiv Ga...   +91 98187 99749
#
#                                               website  \
# 0   https://www.ihg.com/crowneplaza/hotels/us/en/n...
# 1                      http://www.sevenseashotel.com/
# 2   https://www.treebo.com/hotels-in-delhi/treebo-...
# 3                                                 NaN
# 4                       http://www.goelresidency.org/
# 5   https://www.fabhotels.com/hotels-in-new-delhi/...
# 6                  http://svaruchiinn1806.pripgo.com/
# 7                                                 NaN
# 8   https://www.wyndhamhotels.com/ramada/new-delhi...
# 9                   https://shineinnroomsbanquet.com/
# 10                   https://www.oyorooms.com/111489/
# 11                                                NaN
# 12                            http://smresidency.com/
# 13  https://www.oyorooms.com/104220?utm_source=Goo...
# 14                                                NaN
# 15                                                NaN
# 16  https://www.treebo.com/hotels-in-hyderabad/tre...
# 17                   https://www.oyorooms.com/237691/
# 18                                                NaN
# 19                        https://travellershotel.in/
#
#                                           description  \
# 0   Elegant hotel with a spa & 2 restaurants. Refi...
# 1   Refined hotel with dining & a nightclub. Elega...
# 2                                                 NaN
# 3                                                 NaN
# 4   Humble apartment hotel with 10 units. Modest a...
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   Informal hotel with dining & a pool. Relaxed h...
# 9                                                 NaN
# 10                                                NaN
# 11  Relaxed lodging with free breakfast. Warm, mod...
# 12                                                NaN
# 13  Simple budget hotel with a guest kitchen. Stre...
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#                        amenities  rating  reviews price            type_id  \
# 0                   [Free Wi-Fi]     4.4  12182.0  $140              hotel
# 1                            NaN     4.3  10179.0   $97              hotel
# 2   [Free Wi-Fi, Free breakfast]     4.7    115.0   $39              hotel
# 3                   [Free Wi-Fi]     5.0      3.0   $59              hotel
# 4   [Free Wi-Fi, Free breakfast]     4.1    988.0   $10  bed_and_breakfast
# 5                   [Free Wi-Fi]     4.4     41.0   $19              hotel
# 6                            NaN     4.3     16.0   $27              hotel
# 7                   [Free Wi-Fi]     5.0      9.0   $16              hotel
# 8               [Free breakfast]     3.9   2558.0   NaN              hotel
# 9                   [Free Wi-Fi]     4.9     91.0   $11              hotel
# 10                  [Free Wi-Fi]     4.0     64.0   $24              hotel
# 11                           NaN     3.7    167.0   $18              hotel
# 12                  [Free Wi-Fi]     4.5    162.0   $15              hotel
# 13                  [Free Wi-Fi]     3.0    635.0   $14              hotel
# 14                           NaN     3.0     22.0   $19              hotel
# 15                           NaN     NaN      NaN   NaN              hotel
# 16  [Free Wi-Fi, Free breakfast]     4.3    104.0   NaN              hotel
# 17                  [Free Wi-Fi]     2.0      5.0   $12              hotel
# 18                  [Free Wi-Fi]     4.1      7.0   $18  bed_and_breakfast
# 19                           NaN     4.7     68.0   NaN              hotel
#
#                                              type_ids  \
# 0           [hotel, conference_center, wedding_venue]
# 1                                             [hotel]
# 2   [hotel, inn, lodge, motel, private_guest_room,...
# 3                                             [hotel]
# 4                          [bed_and_breakfast, hotel]
# 5                                             [hotel]
# 6                                             [hotel]
# 7                          [hotel, bed_and_breakfast]
# 8                                 [hotel, inn, motel]
# 9                                             [hotel]
# 10  [hotel, bed_and_breakfast, guest_house, holida...
# 11                                            [hotel]
# 12                                            [hotel]
# 13  [hotel, bed_and_breakfast, guest_house, inn, l...
# 14                                            [hotel]
# 15                                            [hotel]
# 16  [hotel, inn, lodge, motel, private_guest_room,...
# 17                                            [hotel]
# 18                   [bed_and_breakfast, guest_house]
# 19                                            [hotel]
#
#                        place_id                                data_id  \
# 0   ChIJ3RlMdckBDTkR0pjpqymKelw  0x390d01c9754c19dd:0x5c7a8a29abe998d2
# 1   ChIJda712aMDDTkRHVw3A7xAp0Q  0x390d03a3d9f5ae75:0x44a740bc03375c1d
# 2   ChIJwcKwnhUDDTkRQWrXJ5HKiRk  0x390d03159eb0c2c1:0x1989ca9127d76a41
# 3   ChIJUXyGwzsBDTkRpCTgSan0Boc  0x390d013bc3867c51:0x8706f4a949e024a4
# 4   ChIJG6b9UeEDDTkRekt9szIwFig  0x390d03e151fda61b:0x28163032b37d4b7a
# 5   ChIJd9sdC4MHDTkRtaltQYd0h2s  0x390d07830b1ddb77:0x6b877487416da9b5
# 6   ChIJJ9zOQXQDDTkRJwENjnlFZNc  0x390d037441cedc27:0xd76445798e0d0127
# 7   ChIJj3VBHVABDTkRbJf3b-WvsDs  0x390d01501d41758f:0x3bb0afe56ff7976c
# 8   ChIJz6cFNNcDDTkR2sR2snMfXUM  0x390d03d73405a7cf:0x435d1f73b276c4da
# 9   ChIJK3r5CKMDDTkR3boHlDA8KE4  0x390d03a308f97a2b:0x4e283c309407badd
# 10  ChIJ2ZLDc-sFDTkR5NCNxtMX1wk   0x390d05eb73c392d9:0x9d717d3c68dd0e4
# 11  ChIJXTx_WucDDTkRQJIErWCG40k  0x390d03e75a7f3c5d:0x49e38660ad049240
# 12  ChIJ1eAJv3EBDTkRh-_kWmP5-nE  0x390d0171bf09e0d5:0x71faf9635ae4ef87
# 13  ChIJM0-S5aAHDTkRRSCWC-TUc4o  0x390d07a0e5924f33:0x8a73d4e40b962045
# 14  ChIJPSB8To8BDTkRMWIbl7Nh0N4  0x390d018f4e7c203d:0xded061b3971b6231
# 15  ChIJAQBD3VUBDTkRUVf3iLf5iYk  0x390d0155dd430001:0x8989f9b788f75751
# 16  ChIJo0kq50oDDTkRW31gcMJK4TY  0x390d034ae72a49a3:0x36e14ac270607d5b
# 17  ChIJm98tDSYHDTkRa_L9K5npxF8  0x390d07260d2ddf9b:0x5fc4e9992bfdf26b
# 18  ChIJU0OZn98DDTkRiZYmE8vgtQ0   0x390d03df9f994353:0xdb5e0cb13269689
# 19  ChIJwV3SeBABDTkRQtfVG9zEhOY  0x390d011078d25dc1:0xe684c4dc1bd5d742
#
#                                          reviews_link    provider_id
# 0   https://serpapi.com/search.json?data_id=0x390d...    /g/1thxtlq7
# 1   https://serpapi.com/search.json?data_id=0x390d...  /g/11b8_mvsd0
# 2   https://serpapi.com/search.json?data_id=0x390d...  /g/11v12t9skk
# 3   https://serpapi.com/search.json?data_id=0x390d...  /g/11v0gkj47x
# 4   https://serpapi.com/search.json?data_id=0x390d...   /g/1hm3qgbcj
# 5   https://serpapi.com/search.json?data_id=0x390d...  /g/11vm7rrvlt
# 6   https://serpapi.com/search.json?data_id=0x390d...  /g/11s7qcm4gy
# 7   https://serpapi.com/search.json?data_id=0x390d...  /g/11tc6qknjz
# 8   https://serpapi.com/search.json?data_id=0x390d...  /g/11j10w00p7
# 9   https://serpapi.com/search.json?data_id=0x390d...  /g/11lcd33w6v
# 10  https://serpapi.com/search.json?data_id=0x390d...  /g/11k34kjvpm
# 11  https://serpapi.com/search.json?data_id=0x390d...  /g/11cmd3zjm0
# 12  https://serpapi.com/search.json?data_id=0x390d...  /g/11s7c7lps1
# 13  https://serpapi.com/search.json?data_id=0x390d...  /g/11h1fyqtjf
# 14  https://serpapi.com/search.json?data_id=0x390d...  /g/11ssznmxf4
# 15  https://serpapi.com/search.json?data_id=0x390d...  /g/11tnxz6lrl
# 16  https://serpapi.com/search.json?data_id=0x390d...  /g/11tfmzvbsh
# 17  https://serpapi.com/search.json?data_id=0x390d...  /g/11vz3qb1_6
# 18  https://serpapi.com/search.json?data_id=0x390d...  /g/11gfkflr9x
# 19  https://serpapi.com/search.json?data_id=0x390d...  /g/11vrh5dl1z

# %%
from web_functions import upload_data_to_spreadsheet
json = '../jsons/gsheets.json'
spreadsheet_key = '1ejSzICfPPYpHL5jeW9zYFI6xf205gbwSdJC-299b6ww'
sheet_names = 'Scraping Data'
upload_data_to_spreadsheet(df, spreadsheet_key, json, sheet_names)

# %%
df3 = pd.read_csv('../scraping_results\places.csv')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\dighz\AppData\Local\Temp\ipykernel_15152\7536612.py:1: SyntaxWarning: invalid escape sequence '\p'
#   df3 = pd.read_csv('../scraping_results\places.csv')

# %%
df3
# Out:
#                                          Title  Rating  Reviews  \
# 0  Layla's Shawarma and Middle Eastern Kitchen     NaN      224
# 1               Alaturka Doner Kebab & Falafel     NaN      794
# 2                               Shish shawarma     NaN      164
# 3                              Falafel express     NaN       54
#
#               Category                                            Address  \
# 0  Lebanese restaurant  G - 28, Market, near Green Park, Green Park Ma...
# 1   Turkish restaurant  G, 64, Rasvilas, near Select Citywalk Mall, Sa...
# 2  Lebanese restaurant                                                NaN
# 3           Restaurant                     H33M+CW4, Delhi, 110037, India
#
#                  Website     Phone Number
# 0  http://www.laylas.in/  +91 97177 27925
# 1                    NaN  +91 99991 78888
# 2                    NaN  +91 99995 62059
# 3                    NaN              NaN
